# %% [markdown]
# # Building an Emoji Predictor

# %% [markdown]
# ### 1. Install the Emoji Package

# %%
# !pip install emoji
# Out:
# ...
# Using legacy 'setup.py install' for emoji, since package 'wheel' is not installed.
# ...
#     Running setup.py install for emoji: started
#     Running setup.py install for emoji: finished with status 'done'
# ...
# WARNING: You are using pip version 20.2.3; however, version 20.2.4 is available.
# You should consider upgrading via the 'c:\python39\python.exe -m pip install --upgrade pip' command.

# %%
import keras

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import sys

# %%
! c:\\users\\abc\\appdata\\local\\programs\\python\\python38\\python.exe -m pip install emoji
# Out:
# ...
# WARNING: You are using pip version 20.2.3; however, version 20.2.4 is available.
# You should consider upgrading via the 'c:\users\abc\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.
#   Using cached emoji-0.6.0.tar.gz (51 kB)
# ...
#   Created wheel for emoji: filename=emoji-0.6.0-py3-none-any.whl size=49720 sha256=72b4ecb0b18cb9fc89db44365992199572c1c791778a9c9a152248029fe45f29
#   Stored in directory: c:\users\abc\appdata\local\pip\cache\wheels\43\3d\82\e7baffa5e86346c6178d7750dba6e8ef063282a37fc563f8f8
# Successfully built emoji
# ...

# %%
import emoji
# had some trouble with the exact installation of a package
# the jupyter system path seems to deviated from the system path of the pip installer
# find corrective measures in the future if possible
# PENDING PROBLEM

# %%
pathname=r"D:\dataScience\machine-learning-online-2018-master\Datasets\glove.6B.50d.txt"

# %%
print(pathname)
# Out:
# D:\dataScience\machine-learning-online-2018-master\Datasets\glove.6B.50d.txt

# %%
! pip --version
# Out:
# pip 20.2.4 from C:\Users\ABC\AppData\Roaming\Python\Python39\site-packages\pip (python 3.9)

# %%
emoji.EMOJI_UNICODE
# Out:
# {':1st_place_medal:': '🥇',
#  ':2nd_place_medal:': '🥈',
#  ':3rd_place_medal:': '🥉',
#  ':AB_button_(blood_type):': '🆎',
#  ':ATM_sign:': '🏧',
#  ':A_button_(blood_type):': '🅰',
#  ':A_button_(blood_type)_selector:': '🅰️',
#  ':Afghanistan:': '🇦🇫',
#  ':Aland_Islands:': '🇦🇽',
#  ':Albania:': '🇦🇱',
#  ':Algeria:': '🇩🇿',
#  ':American_Samoa:': '🇦🇸',
#  ':Andorra:': '🇦🇩',
#  ':Angola:': '🇦🇴',
#  ':Anguilla:': '🇦🇮',
#  ':Antarctica:': '🇦🇶',
#  ':Antigua_&_Barbuda:': '🇦🇬',
#  ':Aquarius:': '♒',
#  ':Argentina:': '🇦🇷',
#  ':Aries:': '♈',
#  ':Armenia:': '🇦🇲',
#  ':Aruba:': '🇦🇼',
#  ':Ascension_Island:': '🇦🇨',
#  ':Australia:': '🇦🇺',
#  ':Austria:': '🇦🇹',
#  ':Azerbaijan:': '🇦🇿',
#  ':BACK_arrow:': '🔙',
#  ':B_button_(blood_type):': '🅱',
#  ':B_button_(blood_type)_selector:': '🅱️',
#  ':Bahamas:': '🇧🇸',
#  ':Bahrain:': '🇧🇭',
#  ':Bangladesh:': '🇧🇩',
#  ':Barbados:': '🇧🇧',
#  ':Belarus:': '🇧🇾',
#  ':Belgium:': '🇧🇪',
#  ':Belize:': '🇧🇿',
#  ':Benin:': '🇧🇯',
#  ':Bermuda:': '🇧🇲',
# ...

# %%
emoji_dictionary={
    "0":"\u2764\uFE0F",
    "1":":baseball:",
    "2":":grinning_face_with_big_eyes:",
    "3":":disappointed_face:",
    "4":":fork_and_knife:",
}

# %%
for e in emoji_dictionary.values():
    print(emoji.emojize(e))
# Out:
# ❤️
# ⚾
# 😃
# 😞
# 🍴

# %% [markdown]
# ### 2. Processing a Custom dataset

# %%
with open(path_to_data+"\emojify_train_x.csv",'r') as train_file:
    all_text=train_file.readlines()

# %%
all_labels=''
with open(path_to_data+"\emojify_Y_train.csv",'r') as label_file:
    all_labels=label_file.readlines()

# %%
X_train=[]
for row in all_text:
    temp=row.split("'")
    for el in temp:
        if el=='' or el=='\n' or el==' ':
            continue
        else:
            X_train.append(el)

# %%
for i,row in enumerate(all_labels):
    split=row.split()
    all_labels[i]=split

# %%
Y_train=[]
for row in all_labels:
    for el in row:
        Y_train.append(int(el))

# %%
X_train=np.array(X_train)

# %%
Y_train=np.array(Y_train)

# %%
X_train=X_train[:-1]

# %%
Y_train.shape
# Out:
# (132,)

# %%
X_train.shape
# Out:
# (132,)

# %%
## we finally are able to get both in the required format, with actual labels

# %% [markdown]
# ### 3. Converting sentences into embeddings

# %%
embedding_dict={}
with open(pathname,'r') as embed:
    for line in embed:
        div=line.split()
        word=div[0]
        embed_values=np.asarray(div[1:],type='float')
        embedding_dict[word]=embed_values
